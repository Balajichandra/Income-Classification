# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('adult.csv')
data.head(5)
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
data.shape
# Out:
# (48842, 15)

# %%
data.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
data.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df = data['workclass'].value_counts()
print(df)
# Out:
# Private             33906
# Self-emp-not-inc     3862
# Local-gov            3136
# ?                    2799
# State-gov            1981
# Self-emp-inc         1695
# Federal-gov          1432
# Without-pay            21
# Never-worked           10
# Name: workclass, dtype: int64

# %%
sns.countplot(x='workclass',data=data)
plt.xticks(rotation=45)
plt.show()

# %%
print(data['native-country'].value_counts())
# Out:
# United-States                 43832
# Mexico                          951
# ?                               857
# Philippines                     295
# Germany                         206
# Puerto-Rico                     184
# Canada                          182
# El-Salvador                     155
# India                           151
# Cuba                            138
# England                         127
# China                           122
# South                           115
# Jamaica                         106
# Italy                           105
# Dominican-Republic              103
# Japan                            92
# Guatemala                        88
# Poland                           87
# Vietnam                          86
# Columbia                         85
# Haiti                            75
# Portugal                         67
# Taiwan                           65
# Iran                             59
# Nicaragua                        49
# ...

# %%
plt.figure(figsize=(20,5))
sns.countplot(x='native-country',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
print(data['relationship'].value_counts())
# Out:
# Husband           19716
# Not-in-family     12583
# Own-child          7581
# Unmarried          5125
# Wife               2331
# Other-relative     1506
# Name: relationship, dtype: int64

# %%
plt.figure(figsize=(10,5))
sns.countplot(x='relationship',data=data)
# Out:
# <AxesSubplot:xlabel='relationship', ylabel='count'>

# %%
print("Number of unique elements in workclass:",data['workclass'].nunique())
print("Number of unique elements in education:",data['education'].nunique())
print("Number of unique elemetns in marital status:",data['marital-status'].nunique())
print("Number of unique class in native country:",data['native-country'].nunique())
# Out:
# Number of unique elements in workclass: 9
# Number of unique elements in education: 16
# Number of unique elemetns in marital status: 7
# Number of unique class in native country: 42

# %%
print(data['income'].value_counts())
# Out:
# <=50K    37155
# >50K     11687
# Name: income, dtype: int64

# %%
sns.countplot(x='income',data=data)
# Out:
# <AxesSubplot:xlabel='income', ylabel='count'>

# %%
print(data['race'].value_counts())
# Out:
# White                 41762
# Black                  4685
# Asian-Pac-Islander     1519
# Amer-Indian-Eskimo      470
# Other                   406
# Name: race, dtype: int64

# %%
sns.countplot(x='race',data=data)
# Out:
# <AxesSubplot:xlabel='race', ylabel='count'>

# %%
print(data['occupation'].value_counts())
# Out:
# Prof-specialty       6172
# Craft-repair         6112
# Exec-managerial      6086
# Adm-clerical         5611
# Sales                5504
# Other-service        4923
# Machine-op-inspct    3022
# ?                    2809
# Transport-moving     2355
# Handlers-cleaners    2072
# Farming-fishing      1490
# Tech-support         1446
# Protective-serv       983
# Priv-house-serv       242
# Armed-Forces           15
# Name: occupation, dtype: int64

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='occupation',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
sns.countplot(x='race',hue='gender',data=data)
# Out:
# <AxesSubplot:xlabel='race', ylabel='count'>

# %%
sns.countplot(x='gender',hue='income',data=data)
# Out:
# <AxesSubplot:xlabel='gender', ylabel='count'>

# %%
sns.countplot(x='race',hue='income',data=data)
# Out:
# <AxesSubplot:xlabel='race', ylabel='count'>

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='education',hue='income',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='workclass',hue='income',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
pd.DataFrame.hist(data,figsize = [15,15])
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='native-country',hue='income',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,5))
sns.countplot(x='native-country',hue='race',data=data)
plt.xticks(rotation=90)
plt.show()

# %%
data[data['income'] =='>50k']['occupation'].value_counts().head(3)
# Out:
# Series([], Name: occupation, dtype: int64)

# %%
pd.crosstab(data['occupation'],data['income']).plot(kind='barh',stacked='True',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='occupation'>
